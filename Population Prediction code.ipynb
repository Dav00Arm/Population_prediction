# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
wp = pd.read_excel('World population database.xls')
wp = wp.set_index(['Country Name'])
wp = wp.drop(['Indicator Code', 'Country Code', 'Indicator Name'],axis=1)
print(wp.shape)
wp.head()
# Out:
# (266, 61)
#                                     1960         1961         1962  \
# Country Name
# Aruba                            54208.0      55434.0      56234.0
# Africa Eastern and Southern  130836765.0  134159786.0  137614644.0
# Afghanistan                    8996967.0    9169406.0    9351442.0
# Africa Western and Central    96396419.0   98407221.0  100506960.0
# Angola                         5454938.0    5531451.0    5608499.0
#
#                                     1963         1964         1965  \
# Country Name
# Aruba                            56699.0      57029.0      57357.0
# Africa Eastern and Southern  141202036.0  144920186.0  148769974.0
# Afghanistan                    9543200.0    9744772.0    9956318.0
# Africa Western and Central   102691339.0  104953470.0  107289875.0
# Angola                         5679409.0    5734995.0    5770573.0
#
#                                     1966         1967         1968  \
# Country Name
# Aruba                            57702.0      58044.0      58377.0
# Africa Eastern and Southern  152752671.0  156876454.0  161156430.0
# Afghanistan                   10174840.0   10399936.0   10637064.0
# Africa Western and Central   109701811.0  112195950.0  114781116.0
# Angola                         5781305.0    5774440.0    5771973.0
#
#                                     1969  ...         2011         2012  \
# Country Name                              ...
# Aruba                            58734.0  ...     102050.0     102565.0
# Africa Eastern and Southern  165611760.0  ...  532760424.0  547482863.0
# Afghanistan                   10893772.0  ...   30117411.0   31161378.0
# Africa Western and Central   117468741.0  ...  360285439.0  370243017.0
# Angola                         5803677.0  ...   24220660.0   25107925.0
#
#                                     2013         2014         2015  \
# Country Name
# Aruba                           103165.0     103776.0     104339.0
# Africa Eastern and Southern  562601578.0  578075373.0  593871847.0
# Afghanistan                   32269592.0   33370804.0   34413603.0
# Africa Western and Central   380437896.0  390882979.0  401586651.0
# Angola                        26015786.0   26941773.0   27884380.0
#
#                                     2016         2017         2018  \
# Country Name
# Aruba                           104865.0     105361.0     105846.0
# Africa Eastern and Southern  609978946.0  626392880.0  643090131.0
# Afghanistan                   35383028.0   36296111.0   37171922.0
# Africa Western and Central   412551299.0  423769930.0  435229381.0
# Angola                        28842482.0   29816769.0   30809787.0
#
#                                     2019         2020
# Country Name
# Aruba                           106310.0     106766.0
# Africa Eastern and Southern  660046272.0  677243299.0
# Afghanistan                   38041757.0   38928341.0
# Africa Western and Central   446911598.0  458803476.0
# Angola                        31825299.0   32866268.0
#
# [5 rows x 61 columns]

# %%
total_population = wp.loc['World']

# %%
fig, ax = plt.subplots(1, 1, figsize=(16,5), dpi= 80)
plt.xlabel('Year', fontsize=15)
plt.ylabel('Population in Billions', fontsize=15)
ax.fill_between(wp.columns[::5],list(total_population.values)[::5], 
                color='r',alpha=0.5, linewidth=3)
ax.set_title('Total world population in years', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Total world population in years')

# %%
countries = wp.drop(['Africa Eastern and Southern', 'Africa Western and Central', 'Arab World',
'Central Europe and the Baltics', 'Caribbean small states', 'East Asia & Pacific (excluding high income)',
'Early-demographic dividend','East Asia & Pacific',
'Europe & Central Asia (excluding high income)','Europe & Central Asia', 'Euro area', 
'European Union','Fragile and conflict affected situations','Heavily indebted poor countries (HIPC)',
'IBRD only','IDA & IBRD total','IDA total','IDA blend','IDA only','Not classified',
'Latin America & Caribbean (excluding high income)','Least developed countries: UN classification',
'Low income','Liechtenstein','Sri Lanka','Lower middle income','Low & middle income','Lesotho',
'Late-demographic dividend','Middle East & North Africa','Middle income','Middle East & North Africa (excluding high income)',
'OECD members','Other small states','Pre-demographic dividend','Pacific island small states','Post-demographic dividend',
'South Asia','Sub-Saharan Africa (excluding high income)','Sub-Saharan Africa','East Asia & Pacific (IDA & IBRD countries)',
'Europe & Central Asia (IDA & IBRD countries)','Latin America & the Caribbean (IDA & IBRD countries)',
'Middle East & North Africa (IDA & IBRD countries)','South Asia (IDA & IBRD)','Sub-Saharan Africa (IDA & IBRD countries)',
'Upper middle income','North America'])

# %%
print(countries.shape)
countries.head()
# Out:
# (218, 61)
#                    1960       1961       1962       1963       1964  \
# Country Name
# Aruba           54208.0    55434.0    56234.0    56699.0    57029.0
# Afghanistan   8996967.0  9169406.0  9351442.0  9543200.0  9744772.0
# Angola        5454938.0  5531451.0  5608499.0  5679409.0  5734995.0
# Albania       1608800.0  1659800.0  1711319.0  1762621.0  1814135.0
# Andorra         13410.0    14378.0    15379.0    16407.0    17466.0
#
#                    1965        1966        1967        1968        1969  ...  \
# Country Name                                                             ...
# Aruba           57357.0     57702.0     58044.0     58377.0     58734.0  ...
# Afghanistan   9956318.0  10174840.0  10399936.0  10637064.0  10893772.0  ...
# Angola        5770573.0   5781305.0   5774440.0   5771973.0   5803677.0  ...
# Albania       1864791.0   1914573.0   1965598.0   2022272.0   2081695.0  ...
# Andorra         18542.0     19646.0     20760.0     21886.0     23053.0  ...
#
#                     2011        2012        2013        2014        2015  \
# Country Name
# Aruba           102050.0    102565.0    103165.0    103776.0    104339.0
# Afghanistan   30117411.0  31161378.0  32269592.0  33370804.0  34413603.0
# Angola        24220660.0  25107925.0  26015786.0  26941773.0  27884380.0
# Albania        2905195.0   2900401.0   2895092.0   2889104.0   2880703.0
# Andorra          83748.0     82427.0     80770.0     79213.0     77993.0
#
#                     2016        2017        2018        2019        2020
# Country Name
# Aruba           104865.0    105361.0    105846.0    106310.0    106766.0
# Afghanistan   35383028.0  36296111.0  37171922.0  38041757.0  38928341.0
# Angola        28842482.0  29816769.0  30809787.0  31825299.0  32866268.0
# Albania        2876101.0   2873457.0   2866376.0   2854191.0   2837743.0
# Andorra          77295.0     76997.0     77008.0     77146.0     77265.0
#
# [5 rows x 61 columns]

# %%
correction = {'Congo, Dem. Rep.': 'Dem. Rep. Congo',
        'Congo, Dem.':'Dem. Congo',
        'Egypt, Arab Rep.': 'Arab Rep. Egypt',
        'Micronesia, Fed. Sts.': 'Fed. Sts. Micronesia',
        'Korea, Rep.': 'Rep. Korea',
        "Korea, Dem. People's Rep.": 'North Korea',
        'Venezuela, RB': 'Venezuela',
        'Yemen, Rep.': 'Rep. Yemen'}

countries = countries.rename(index=correction)

# %%
countries.tail()
# Out:
#                     1960        1961        1962        1963        1964  \
# Country Name
# Kosovo          947000.0    966000.0    994000.0   1022000.0   1050000.0
# Rep. Yemen     5315351.0   5393034.0   5473671.0   5556767.0   5641598.0
# South Africa  17099836.0  17524533.0  17965733.0  18423157.0  18896303.0
# Zambia         3070780.0   3164330.0   3260645.0   3360099.0   3463211.0
# Zimbabwe       3776679.0   3905038.0   4039209.0   4178726.0   4322854.0
#
#                     1965        1966        1967        1968        1969  ...  \
# Country Name                                                              ...
# Kosovo         1078000.0   1106000.0   1135000.0   1163000.0   1191000.0  ...
# Rep. Yemen     5727745.0   5816241.0   5907873.0   6001858.0   6097042.0  ...
# South Africa  19384838.0  19888259.0  20406863.0  20942147.0  21496075.0  ...
# Zambia         3570466.0   3681953.0   3797877.0   3918872.0   4045740.0  ...
# Zimbabwe       4471178.0   4623340.0   4779825.0   4941901.0   5111326.0  ...
#
#                     2011        2012        2013        2014        2015  \
# Country Name
# Kosovo         1791000.0   1807106.0   1818117.0   1812771.0   1788196.0
# Rep. Yemen    23807586.0  24473176.0  25147112.0  25823488.0  26497881.0
# South Africa  52003759.0  52832659.0  53687125.0  54544184.0  55386369.0
# Zambia        14023199.0  14465148.0  14926551.0  15399793.0  15879370.0
# Zimbabwe      12894323.0  13115149.0  13350378.0  13586710.0  13814642.0
#
#                     2016        2017        2018        2019        2020
# Country Name
# Kosovo         1777557.0   1791003.0   1797085.0   1788878.0   1775378.0
# Rep. Yemen    27168210.0  27834811.0  28498683.0  29161922.0  29825968.0
# South Africa  56207649.0  57009751.0  57792520.0  58558267.0  59308690.0
# Zambia        16363449.0  16853608.0  17351714.0  17861034.0  18383956.0
# Zimbabwe      14030338.0  14236599.0  14438812.0  14645473.0  14862927.0
#
# [5 rows x 61 columns]

# %%
countries[countries.isna().any(axis=1)]
# Out:
#                          1960       1961       1962       1963       1964  \
# Country Name
# Eritrea             1007586.0  1033320.0  1060489.0  1088859.0  1118152.0
# Kuwait               269026.0   300581.0   337346.0   378756.0   423900.0
# West Bank and Gaza        NaN        NaN        NaN        NaN        NaN
#
#                          1965       1966       1967       1968       1969  \
# Country Name
# Eritrea             1148188.0  1178875.0  1210304.0  1242633.0  1276122.0
# Kuwait               472032.0   523169.0   577164.0   632911.0   688972.0
# West Bank and Gaza        NaN        NaN        NaN        NaN        NaN
#
#                     ...       2011       2012       2013       2014  \
# Country Name        ...
# Eritrea             ...  3213969.0        NaN        NaN        NaN
# Kuwait              ...  3168054.0  3348852.0  3526382.0  3690939.0
# West Bank and Gaza  ...  3882986.0  3979998.0  4076708.0  4173398.0
#
#                          2015       2016       2017       2018       2019  \
# Country Name
# Eritrea                   NaN        NaN        NaN        NaN        NaN
# Kuwait              3835588.0  3956862.0  4056102.0  4137314.0  4207077.0
# West Bank and Gaza  4270092.0  4367088.0  4454805.0  4569087.0  4685306.0
#
#                          2020
# Country Name
# Eritrea                   NaN
# Kuwait              4270563.0
# West Bank and Gaza  4803269.0
#
# [3 rows x 61 columns]

# %%
countries.loc['Eritrea'] = countries.loc['Eritrea'].fillna(countries.loc['Eritrea','1969'])
countries.loc['West Bank and Gaza'] = countries.loc['West Bank and Gaza'].fillna(countries.loc['West Bank and Gaza','1990'])
kuwait_avg = (countries.loc['Kuwait','1991'] + countries.loc['Kuwait','1995'])/2
countries.loc['Kuwait'] = countries.loc['Kuwait'].fillna(kuwait_avg)

# %%
fig, ax = plt.subplots(2,1, figsize=(12,10),sharex=True)
fig.suptitle('Population of China and Armenia', fontsize=18)
ax[0].set_title('China', fontsize=(15))
ax[1].set_title('Armenia', fontsize=(15))
ax[0].fill_between(countries.columns[::5],list(countries.loc[['China']].values[0])[::5], 
                color='r',alpha=0.5, linewidth=2)
ax[1].fill_between(countries.columns[::5],list(countries.loc[['Armenia']].values[0])[::5], 
                color='b',alpha=0.5, linewidth=2)
ax[0].set(ylabel='Population in Billions')
ax[1].set(ylabel='Population in Millions')
# Out:
# [Text(0, 0.5, 'Population in Millions')]

# %%
countries_transpose = countries.T
countries_transpose
# Out:
# Country Name     Aruba  Afghanistan      Angola    Albania  Andorra  \
# 1960           54208.0    8996967.0   5454938.0  1608800.0  13410.0
# 1961           55434.0    9169406.0   5531451.0  1659800.0  14378.0
# 1962           56234.0    9351442.0   5608499.0  1711319.0  15379.0
# 1963           56699.0    9543200.0   5679409.0  1762621.0  16407.0
# 1964           57029.0    9744772.0   5734995.0  1814135.0  17466.0
# ...                ...          ...         ...        ...      ...
# 2016          104865.0   35383028.0  28842482.0  2876101.0  77295.0
# 2017          105361.0   36296111.0  29816769.0  2873457.0  76997.0
# 2018          105846.0   37171922.0  30809787.0  2866376.0  77008.0
# 2019          106310.0   38041757.0  31825299.0  2854191.0  77146.0
# 2020          106766.0   38928341.0  32866268.0  2837743.0  77265.0
#
# Country Name  United Arab Emirates   Argentina    Armenia  American Samoa  \
# 1960                       92417.0  20481781.0  1874119.0         20127.0
# 1961                      100801.0  20817270.0  1941498.0         20605.0
# 1962                      112112.0  21153042.0  2009524.0         21246.0
# 1963                      125130.0  21488916.0  2077584.0         22029.0
# 1964                      138049.0  21824427.0  2145004.0         22850.0
# ...                            ...         ...        ...             ...
# 2016                     9360975.0  43590368.0  2936147.0         55739.0
# 2017                     9487206.0  44044811.0  2944789.0         55617.0
# 2018                     9630966.0  44494502.0  2951741.0         55461.0
# 2019                     9770526.0  44938712.0  2957728.0         55312.0
# 2020                     9890400.0  45376763.0  2963234.0         55197.0
#
# Country Name  Antigua and Barbuda  ...  Virgin Islands (U.S.)     Vietnam  \
# 1960                      54132.0  ...                32500.0  32670048.0
# 1961                      55005.0  ...                34300.0  33666111.0
# 1962                      55849.0  ...                35000.0  34683410.0
# 1963                      56701.0  ...                39800.0  35721213.0
# 1964                      57641.0  ...                40800.0  36780001.0
# ...                           ...  ...                    ...         ...
# 2016                      94520.0  ...               107516.0  93640435.0
# 2017                      95425.0  ...               107281.0  94600643.0
# 2018                      96282.0  ...               107001.0  95545959.0
# 2019                      97115.0  ...               106669.0  96462108.0
# 2020                      97928.0  ...               106290.0  97338583.0
#
# Country Name   Vanuatu         World     Samoa     Kosovo  Rep. Yemen  \
# 1960           63689.0  3.032156e+09  108627.0   947000.0   5315351.0
# 1961           65700.0  3.071596e+09  112112.0   966000.0   5393034.0
# 1962           67793.0  3.124561e+09  115768.0   994000.0   5473671.0
# 1963           69944.0  3.189656e+09  119552.0  1022000.0   5556767.0
# 1964           72116.0  3.255146e+09  123346.0  1050000.0   5641598.0
# ...                ...           ...       ...        ...         ...
# 2016          278326.0  7.424485e+09  194540.0  1777557.0  27168210.0
# 2017          285499.0  7.509410e+09  195358.0  1791003.0  27834811.0
# 2018          292675.0  7.592476e+09  196128.0  1797085.0  28498683.0
# 2019          299882.0  7.673345e+09  197093.0  1788878.0  29161922.0
# 2020          307150.0  7.752841e+09  198410.0  1775378.0  29825968.0
#
# Country Name  South Africa      Zambia    Zimbabwe
# 1960            17099836.0   3070780.0   3776679.0
# 1961            17524533.0   3164330.0   3905038.0
# 1962            17965733.0   3260645.0   4039209.0
# 1963            18423157.0   3360099.0   4178726.0
# 1964            18896303.0   3463211.0   4322854.0
# ...                    ...         ...         ...
# 2016            56207649.0  16363449.0  14030338.0
# 2017            57009751.0  16853608.0  14236599.0
# 2018            57792520.0  17351714.0  14438812.0
# 2019            58558267.0  17861034.0  14645473.0
# 2020            59308690.0  18383956.0  14862927.0
#
# [61 rows x 218 columns]

# %%
countries_transpose.index = pd.to_datetime(countries_transpose.index).year
countries_transpose.head()
# Out:
# Country Name    Aruba  Afghanistan     Angola    Albania  Andorra  \
# 1960          54208.0    8996967.0  5454938.0  1608800.0  13410.0
# 1961          55434.0    9169406.0  5531451.0  1659800.0  14378.0
# 1962          56234.0    9351442.0  5608499.0  1711319.0  15379.0
# 1963          56699.0    9543200.0  5679409.0  1762621.0  16407.0
# 1964          57029.0    9744772.0  5734995.0  1814135.0  17466.0
#
# Country Name  United Arab Emirates   Argentina    Armenia  American Samoa  \
# 1960                       92417.0  20481781.0  1874119.0         20127.0
# 1961                      100801.0  20817270.0  1941498.0         20605.0
# 1962                      112112.0  21153042.0  2009524.0         21246.0
# 1963                      125130.0  21488916.0  2077584.0         22029.0
# 1964                      138049.0  21824427.0  2145004.0         22850.0
#
# Country Name  Antigua and Barbuda  ...  Virgin Islands (U.S.)     Vietnam  \
# 1960                      54132.0  ...                32500.0  32670048.0
# 1961                      55005.0  ...                34300.0  33666111.0
# 1962                      55849.0  ...                35000.0  34683410.0
# 1963                      56701.0  ...                39800.0  35721213.0
# 1964                      57641.0  ...                40800.0  36780001.0
#
# Country Name  Vanuatu         World     Samoa     Kosovo  Rep. Yemen  \
# 1960          63689.0  3.032156e+09  108627.0   947000.0   5315351.0
# 1961          65700.0  3.071596e+09  112112.0   966000.0   5393034.0
# 1962          67793.0  3.124561e+09  115768.0   994000.0   5473671.0
# 1963          69944.0  3.189656e+09  119552.0  1022000.0   5556767.0
# 1964          72116.0  3.255146e+09  123346.0  1050000.0   5641598.0
#
# Country Name  South Africa     Zambia   Zimbabwe
# 1960            17099836.0  3070780.0  3776679.0
# 1961            17524533.0  3164330.0  3905038.0
# 1962            17965733.0  3260645.0  4039209.0
# 1963            18423157.0  3360099.0  4178726.0
# 1964            18896303.0  3463211.0  4322854.0
#
# [5 rows x 218 columns]

# %%
countries_transpose['Armenia'].plot()
# Out:
# <AxesSubplot:>

# %%
from pandas.plotting import autocorrelation_plot

autocorrelation_plot(countries_transpose['Armenia'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(countries_transpose['Armenia'])
plt.show()

# %%
Armenia_diff = countries_transpose['Armenia'].diff(periods=1)[1:]
Armenia_diff.plot()
# Out:
# <AxesSubplot:>

# %%
import pmdarima as pm

model = pm.auto_arima(countries_transpose['Armenia'], start_p=1, start_q=1,
                      test='adf',       
                      max_p=4, max_q=4, m=1,
                      seasonal=False,   
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=inf, Time=0.19 sec
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=1248.062, Time=0.01 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=1350.663, Time=0.05 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=1250.915, Time=0.04 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=1246.862, Time=0.01 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.310 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   61
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                -622.431
# Date:                Thu, 11 Nov 2021   AIC                           1246.862
# Time:                        00:45:31   BIC                           1248.939
# Sample:                             0   HQIC                          1247.673
#                                  - 61
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      8.244e+07   7.76e+06     10.617      0.000    6.72e+07    9.77e+07
# ===================================================================================
# Ljung-Box (L1) (Q):                  47.04   Jarque-Bera (JB):                79.30
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              10.36   Skew:                            -1.74
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.49
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
n_periods = 10
forecast, confint = model.predict(n_periods=n_periods, return_conf_int=True)
forecast_id = pd.date_range(start='2021/01/01', periods=n_periods,freq='YS').year
forecast_series = pd.Series(forecast.round(decimals=0), index=forecast_id)
lower_series = pd.Series(confint[:, 0].round(decimals=0), index=forecast_id)
upper_series = pd.Series(confint[:, 1].round(decimals=0), index=forecast_id)

plt.figure(figsize=(10,8))
plt.plot(countries_transpose['Armenia'])
plt.plot(forecast_series)
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("Final Forecast")
plt.show()

preds = pd.concat({'forecast':forecast_series,'lower border': lower_series, 'upper border': upper_series}, axis=1)
preds.astype('int')
# Out:
#       forecast  lower border  upper border
# 2021   2968740       2950944       2986536
# 2022   2974246       2934454       3014038
# 2023   2979752       2913166       3046338
# 2024   2985258       2887787       3082729
# 2025   2990764       2858787       3122741
# 2026   2996270       2826510       3166030
# 2027   3001776       2791214       3212338
# 2028   3007282       2753108       3261456
# 2029   3012788       2712362       3313214
# 2030   3018294       2669117       3367471
